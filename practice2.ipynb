# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\hp\Desktop\Data sceince projects\Company_dirty2.csv.csv', encoding='latin1')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      30 non-null     int64
#  1   Name            30 non-null     object
#  2   Email           30 non-null     object
#  3   Age             30 non-null     float64
#  4   Country         30 non-null     object
#  5   PurchaseAmount  21 non-null     float64
#  6   SignupDate      30 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.8+ KB

# %%
data['Age'] = np.where(data["Age"] < 18 , np.nan ,data['Age'] )

# %%
data['Age'] = np.where(data['Age'] > 100, np.nan, data['Age'])

# %%
data['PurchaseAmount'] = np.where(data['PurchaseAmount'] < 0, np.nan, data['PurchaseAmount'])
data
# Out:
#     CustomerID             Name                        Email    Age  Country  \
# 0            1       Jane Smith       jane.smith@example.com    NaN    Naija
# 1            2  Michael Johnson        michael.johnson@gmail  19.00  Nigeria
# 2            3     Fatima Bello           fatima.bello@gmail  43.57       UK
# 3            4      Samuel Okon      samuel.okon@company.com    NaN    Naija
# 4            5        Grace Lee        grace.lee@company.com    NaN  Nigeria
# 5            6  Michael Johnson  michael.johnson@company.com    NaN    Ghana
# 6            7       Jane Smith             jane.smith@gmail  43.57    Ghana
# 7            8      David James      david.james@example.com    NaN       UK
# 8            9     Fatima Bello          fatima.bello@domain  56.00    Naija
# 9           10  Michael Johnson  michael.johnson@company.com  43.57      USA
# 10          11     Fatima Bello                fatima.bello@  43.57       UK
# ...

# %%
data.drop_duplicates(inplace=Tru
# Out:
#   Cell In[44], line 1
#     data.drop_duplicates(inplace=Tru
#                                     ^
# _IncompleteInputError: incomplete input

# %%
data
# Out:
#     CustomerID             Name                        Email    Age  Country  \
# 0            1       Jane Smith       jane.smith@example.com    NaN    Naija
# 1            2  Michael Johnson        michael.johnson@gmail  19.00  Nigeria
# 2            3     Fatima Bello           fatima.bello@gmail  43.57       UK
# 3            4      Samuel Okon      samuel.okon@company.com    NaN    Naija
# 4            5        Grace Lee        grace.lee@company.com    NaN  Nigeria
# 5            6  Michael Johnson  michael.johnson@company.com    NaN    Ghana
# 6            7       Jane Smith             jane.smith@gmail  43.57    Ghana
# 7            8      David James      david.james@example.com    NaN       UK
# 8            9     Fatima Bello          fatima.bello@domain  56.00    Naija
# 9           10  Michael Johnson  michael.johnson@company.com  43.57      USA
# 10          11     Fatima Bello                fatima.bello@  43.57       UK
# ...

# %%
data['Age'].fillna(0, inplace = True)
data
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_736\1566325126.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(0, inplace = True)
#     CustomerID             Name                        Email    Age  Country  \
# 0            1       Jane Smith       jane.smith@example.com   0.00    Naija
# 1            2  Michael Johnson        michael.johnson@gmail  19.00  Nigeria
# 2            3     Fatima Bello           fatima.bello@gmail  43.57       UK
# ...

# %%
data['Age'].fillna(data['Age'].mean(), inplace = True)
data
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_736\1047361643.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data['Age'].mean(), inplace = True)
#     CustomerID             Name                        Email    Age  Country  \
# 0            1       Jane Smith       jane.smith@example.com   0.00    Naija
# 1            2  Michael Johnson        michael.johnson@gmail  19.00  Nigeria
# 2            3     Fatima Bello           fatima.bello@gmail  43.57       UK
# ...

# %%
data['Age'].replace(0.00, data['Age'].mean(), inplace= True)
data
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_736\334888419.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].replace(0.00, data['Age'].mean(), inplace= True)
#     CustomerID             Name                        Email        Age  \
# 0            1       Jane Smith       jane.smith@example.com  30.423333
# 1            2  Michael Johnson        michael.johnson@gmail  19.000000
# 2            3     Fatima Bello           fatima.bello@gmail  43.570000
# ...

# %%
data['PurchaseAmount'].fillna(0, inplace=True)
data
# Out:
#     CustomerID             Name                        Email        Age  \
# 0            1       Jane Smith       jane.smith@example.com  30.423333
# 1            2  Michael Johnson        michael.johnson@gmail  19.000000
# 2            3     Fatima Bello           fatima.bello@gmail  43.570000
# 3            4      Samuel Okon      samuel.okon@company.com  30.423333
# 4            5        Grace Lee        grace.lee@company.com  30.423333
# 5            6  Michael Johnson  michael.johnson@company.com  30.423333
# 6            7       Jane Smith             jane.smith@gmail  43.570000
# 7            8      David James      david.james@example.com  30.423333
# 8            9     Fatima Bello          fatima.bello@domain  56.000000
# 9           10  Michael Johnson  michael.johnson@company.com  43.570000
# 10          11     Fatima Bello                fatima.bello@  43.570000
# 11          12         John Doe         john.doe@example.com  30.423333
# ...

# %%
data['PurchaseAmount'].replace(0.00, data['PurchaseAmount'].mean(), inplace=True)
data
# Out:
#     CustomerID             Name                        Email        Age  \
# 0            1       Jane Smith       jane.smith@example.com  30.423333
# 1            2  Michael Johnson        michael.johnson@gmail  19.000000
# 2            3     Fatima Bello           fatima.bello@gmail  43.570000
# 3            4      Samuel Okon      samuel.okon@company.com  30.423333
# 4            5        Grace Lee        grace.lee@company.com  30.423333
# 5            6  Michael Johnson  michael.johnson@company.com  30.423333
# 6            7       Jane Smith             jane.smith@gmail  43.570000
# 7            8      David James      david.james@example.com  30.423333
# 8            9     Fatima Bello          fatima.bello@domain  56.000000
# 9           10  Michael Johnson  michael.johnson@company.com  43.570000
# 10          11     Fatima Bello                fatima.bello@  43.570000
# 11          12         John Doe         john.doe@example.com  30.423333
# ...

# %%
data
# Out:
# 0     Nigeria
# 1     Nigeria
# 2          UK
# 3     Nigeria
# 4     Nigeria
# 5       Ghana
# 6       Ghana
# 7          UK
# 8     Nigeria
# 9         USA
# 10         UK
# 11      Ghana
# 12      Ghana
# 13    Nigeria
# 14    Nigeria
# 15    Nigeria
# 16         UK
# 17    Nigeria
# 18    Nigeria
# 19    Nigeria
# 20      Ghana
# 21    Nigeria
# 22      Ghana
# 23        NGR
# 24    Nigeria
# 25        USA
# 26    Nigeria
# 27         UK
# 28        USA
# 29        NGR
# Name: Country, dtype: object

# %%
data
# Out:
# 0     Nigeria
# 1     Nigeria
# 2          UK
# 3     Nigeria
# 4     Nigeria
# 5       Ghana
# 6       Ghana
# 7          UK
# 8     Nigeria
# 9         USA
# 10         UK
# 11      Ghana
# 12      Ghana
# 13    Nigeria
# 14    Nigeria
# 15    Nigeria
# 16         UK
# 17    Nigeria
# 18    Nigeria
# 19    Nigeria
# 20      Ghana
# 21    Nigeria
# 22      Ghana
# 23        NGR
# 24    Nigeria
# 25        USA
# 26    Nigeria
# 27         UK
# 28        USA
# 29        NGR
# Name: Country, dtype: object
