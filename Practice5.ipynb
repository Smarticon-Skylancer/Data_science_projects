# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r'C:\Users\hp\Desktop\Data sceince projects\messy_dataset (1).csv', encoding="latin1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      510 non-null    int64
#  1   Name            510 non-null    object
#  2   Age             480 non-null    float64
#  3   Gender          386 non-null    object
#  4   Country         414 non-null    object
#  5   Email           465 non-null    object
#  6   PurchaseAmount  481 non-null    float64
#  7   JoinDate        510 non-null    object
#  8   LastLogin       510 non-null    object
#  9   IsActive        471 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 40.0+ KB

# %%
df['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 510 entries, 0 to 509
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 480 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %%
missing_percentage= df.isnull().sum()/len(df)*100
missing_percentage
# Out:
# CustomerID         0.000000
# Name               0.000000
# Age                5.882353
# Gender            24.313725
# Country           18.823529
# Email              8.823529
# PurchaseAmount     5.686275
# JoinDate           0.000000
# LastLogin          0.000000
# IsActive           7.647059
# dtype: float64

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df["PurchaseAmount"].fillna(df['PurchaseAmount'].mean(), inplace = True )
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3216\1648371337.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_3216\1648371337.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
df
# Out:
#      CustomerID            Name        Age  Gender  Country  \
# 0             1    Bob Williams  56.000000   Other       UK
# 1             2   Diana Johnson  69.000000   Other    India
# 2             3       Eve Brown  46.000000     NaN      NaN
# 3             4     Henry Jones  32.000000     NaN      NaN
# 4             5     Frank Smith  60.000000     NaN      USA
# ..          ...             ...        ...     ...      ...
# 505         395   Frank Johnson  34.000000   Other  Nigeria
# 506         378     Grace Brown  44.091667     NaN  Nigeria
# 507         125     Diana Smith  22.000000     NaN      USA
# 508          69  Henry Williams  34.000000  Female    India
# 509         451   Alice Johnson  52.000000    Male    India
#
#                    Email  PurchaseAmount    JoinDate   LastLogin IsActive
# 0      frank61@gmail.com          128.32  2023-05-13  2022-08-05    False
# 1    charlie20@gmail.com          522.52  2018-07-11  2021-01-15    False
# ...

# %%
df["Age"] = np.where(df['Age'] < 18, np.delete, df['Age'])
df["Age"] = np.where(df['Age'] > 100, np.delete, df['Age'])

df
# Out:
#      CustomerID            Name        Age  Gender  Country  \
# 0             1    Bob Williams       56.0   Other       UK
# 1             2   Diana Johnson       69.0   Other    India
# 2             3       Eve Brown       46.0     NaN      NaN
# 3             4     Henry Jones       32.0     NaN      NaN
# 4             5     Frank Smith       60.0     NaN      USA
# ..          ...             ...        ...     ...      ...
# 505         395   Frank Johnson       34.0   Other  Nigeria
# 506         378     Grace Brown  44.091667     NaN  Nigeria
# 507         125     Diana Smith       22.0     NaN      USA
# 508          69  Henry Williams       34.0  Female    India
# 509         451   Alice Johnson       52.0    Male    India
#
#                    Email  PurchaseAmount    JoinDate   LastLogin IsActive
# 0      frank61@gmail.com          128.32  2023-05-13  2022-08-05    False
# 1    charlie20@gmail.com          522.52  2018-07-11  2021-01-15    False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      510 non-null    int64
#  1   Name            510 non-null    object
#  2   Age             510 non-null    object
#  3   Gender          386 non-null    object
#  4   Country         414 non-null    object
#  5   Email           465 non-null    object
#  6   PurchaseAmount  510 non-null    float64
#  7   JoinDate        510 non-null    object
#  8   LastLogin       510 non-null    object
#  9   IsActive        471 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 40.0+ KB

# %%
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df[df['Gender'] != 'None']
# Out:
#      CustomerID            Name        Age  Gender  Country  \
# 0             1    Bob Williams       56.0   Other       UK
# 1             2   Diana Johnson       69.0   Other    India
# 2             3       Eve Brown       46.0     NaN      NaN
# 3             4     Henry Jones       32.0     NaN      NaN
# 4             5     Frank Smith       60.0     NaN      USA
# ..          ...             ...        ...     ...      ...
# 505         395   Frank Johnson       34.0   Other  Nigeria
# 506         378     Grace Brown  44.091667     NaN  Nigeria
# 507         125     Diana Smith       22.0     NaN      USA
# 508          69  Henry Williams       34.0  Female    India
# 509         451   Alice Johnson       52.0    Male    India
#
#                    Email  PurchaseAmount    JoinDate   LastLogin IsActive
# 0      frank61@gmail.com          128.32  2023-05-13  2022-08-05    False
# 1    charlie20@gmail.com          522.52  2018-07-11  2021-01-15    False
# ...

# %%
df['Gender'].replace('Other','Male' , inplace=True)
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3216\1395349483.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace('Other','Male' , inplace=True)
#      CustomerID            Name        Age  Gender  Country  \
# 0             1    Bob Williams       56.0    Male       UK
# 1             2   Diana Johnson       69.0    Male    India
# 2             3       Eve Brown       46.0     NaN      NaN
# 3             4     Henry Jones       32.0     NaN      NaN
# ...

# %%
df['Gender'].fillna("Other", inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3216\3352314477.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna("Other", inplace=True)

# %%
df
# Out:
#      CustomerID            Name        Age  Gender  Country  \
# 0             1    Bob Williams       56.0    Male       UK
# 1             2   Diana Johnson       69.0    Male    India
# 2             3       Eve Brown       46.0   Other      NaN
# 3             4     Henry Jones       32.0   Other      NaN
# 4             5     Frank Smith       60.0   Other      USA
# ..          ...             ...        ...     ...      ...
# 505         395   Frank Johnson       34.0    Male  Nigeria
# 506         378     Grace Brown  44.091667   Other  Nigeria
# 507         125     Diana Smith       22.0   Other      USA
# 508          69  Henry Williams       34.0  Female    India
# 509         451   Alice Johnson       52.0    Male    India
#
#                    Email  PurchaseAmount    JoinDate   LastLogin IsActive
# 0      frank61@gmail.com          128.32  2023-05-13  2022-08-05    False
# 1    charlie20@gmail.com          522.52  2018-07-11  2021-01-15    False
# ...

# %%
df.drop(df[df['Gender']=='Other']. index, inplace=True)
df
# Out:
#      CustomerID              Name   Age  Gender  Country                Email  \
# 0             1      Bob Williams  56.0    Male       UK    frank61@gmail.com
# 1             2     Diana Johnson  69.0    Male    India  charlie20@gmail.com
# 5             6       Frank Brown  25.0    Male  Nigeria    frank65@gmail.com
# 6             7       Alice Jones  38.0  Female  Nigeria    frank93@gmail.com
# 8             9       Henry Smith  36.0  Female    India    diana86@gmail.com
# ..          ...               ...   ...     ...      ...                  ...
# 501          74  Charlie Williams  19.0  Female    India    frank23@gmail.com
# 502         375       Henry Smith  55.0  Female  Nigeria    frank87@gmail.com
# 505         395     Frank Johnson  34.0    Male  Nigeria    henry50@gmail.com
# 508          69    Henry Williams  34.0  Female    India    grace71@gmail.com
# 509         451     Alice Johnson  52.0    Male    India    diana72@gmail.com
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 386 entries, 0 to 509
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      386 non-null    int64
#  1   Name            386 non-null    object
#  2   Age             386 non-null    object
#  3   Gender          386 non-null    object
#  4   Country         312 non-null    object
#  5   Email           353 non-null    object
#  6   PurchaseAmount  386 non-null    float64
#  7   JoinDate        386 non-null    object
#  8   LastLogin       386 non-null    object
#  9   IsActive        355 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 33.2+ KB

# %%
duplicates= df.duplicated().sum()
print("duplicates : ", duplicates)
# Out:
# duplicates :  6

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      CustomerID            Name   Age  Gender  Country                Email  \
# 0             1    Bob Williams  56.0    Male       UK    frank61@gmail.com
# 1             2   Diana Johnson  69.0    Male    India  charlie20@gmail.com
# 5             6     Frank Brown  25.0    Male  Nigeria    frank65@gmail.com
# 6             7     Alice Jones  38.0  Female  Nigeria    frank93@gmail.com
# 8             9     Henry Smith  36.0  Female    India    diana86@gmail.com
# ..          ...             ...   ...     ...      ...                  ...
# 494         495     Frank Smith  23.0    Male    India  charlie71@gmail.com
# 495         496  Alice Williams  62.0    Male      NaN    diana18@gmail.com
# 496         497  Grace Williams  49.0  Female  Nigeria    grace17@gmail.com
# 498         499    Bob Williams  47.0    Male      USA  charlie68@gmail.com
# 499         500    Bob Williams  64.0  Female      USA  charlie65@gmail.com
#
#      PurchaseAmount    JoinDate   LastLogin IsActive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 380 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      380 non-null    int64
#  1   Name            380 non-null    object
#  2   Age             380 non-null    object
#  3   Gender          380 non-null    object
#  4   Country         307 non-null    object
#  5   Email           347 non-null    object
#  6   PurchaseAmount  380 non-null    float64
#  7   JoinDate        380 non-null    object
#  8   LastLogin       380 non-null    object
#  9   IsActive        350 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 32.7+ KB

# %%
df['Country'].mode()[0]
# Out:
# 'USA'

# %%
df['Country'].fillna(df['Country'].mode(), inplace=True)
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3216\1563142254.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Country'].fillna(df['Country'].mode(), inplace=True)
#      CustomerID            Name   Age  Gender  Country                Email  \
# 0             1    Bob Williams  56.0    Male       UK    frank61@gmail.com
# 1             2   Diana Johnson  69.0    Male    India  charlie20@gmail.com
# 5             6     Frank Brown  25.0    Male  Nigeria    frank65@gmail.com
# ...

# %%
missing_percentage
# Out:
# CustomerID         0.000000
# Name               0.000000
# Age                5.882353
# Gender            24.313725
# Country           18.823529
# Email              8.823529
# PurchaseAmount     5.686275
# JoinDate           0.000000
# LastLogin          0.000000
# IsActive           7.647059
# dtype: float64

# %%
df["Age"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 380 entries, 0 to 499
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 380 non-null    object
# dtypes: object(1)
# memory usage: 5.9+ KB

# %%
missing_percentage= df.isnull().sum()/len(df)*100
missing_percentage
# Out:
# CustomerID         0.000000
# Name               0.000000
# Age                0.000000
# Gender             0.000000
# Country           19.210526
# Email              8.684211
# PurchaseAmount     0.000000
# JoinDate           0.000000
# LastLogin          0.000000
# IsActive           7.894737
# dtype: float64

# %%
df['Country'].fillna(df['Country'].mode(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 380 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      380 non-null    int64
#  1   Name            380 non-null    object
#  2   Age             380 non-null    object
#  3   Gender          380 non-null    object
#  4   Country         307 non-null    object
#  5   Email           347 non-null    object
#  6   PurchaseAmount  380 non-null    float64
#  7   JoinDate        380 non-null    object
#  8   LastLogin       380 non-null    object
#  9   IsActive        350 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 32.7+ KB

# %%
df.drop(columns=['Email'], inplace=True)
df
# Out:
#      CustomerID            Name   Age  Gender  Country  PurchaseAmount  \
# 0             1    Bob Williams  56.0    Male       UK          128.32
# 1             2   Diana Johnson  69.0    Male    India          522.52
# 5             6     Frank Brown  25.0    Male  Nigeria          931.37
# 6             7     Alice Jones  38.0  Female  Nigeria          569.20
# 8             9     Henry Smith  36.0  Female    India          545.51
# ..          ...             ...   ...     ...      ...             ...
# 494         495     Frank Smith  23.0    Male    India          202.12
# 495         496  Alice Williams  62.0    Male      NaN           19.20
# 496         497  Grace Williams  49.0  Female  Nigeria          186.76
# 498         499    Bob Williams  47.0    Male      USA          284.57
# 499         500    Bob Williams  64.0  Female      USA          203.63
#
#        JoinDate   LastLogin IsActive
# 0    2023-05-13  2022-08-05    False
# 1    2018-07-11  2021-01-15    False
# ...

# %%
df["Country"].fillna('Unavailable', inplace=True)
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3216\1341375453.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Country"].fillna('Unavailable', inplace=True)
#      CustomerID            Name   Age  Gender      Country  PurchaseAmount  \
# 0             1    Bob Williams  56.0    Male           UK          128.32
# 1             2   Diana Johnson  69.0    Male        India          522.52
# 5             6     Frank Brown  25.0    Male      Nigeria          931.37
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 380 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      380 non-null    int64
#  1   Name            380 non-null    object
#  2   Age             380 non-null    object
#  3   Gender          380 non-null    object
#  4   Country         380 non-null    object
#  5   PurchaseAmount  380 non-null    float64
#  6   JoinDate        380 non-null    object
#  7   LastLogin       380 non-null    object
#  8   IsActive        350 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 29.7+ KB

# %%
df['IsActive'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 380 entries, 0 to 499
# Series name: IsActive
# Non-Null Count  Dtype
# --------------  -----
# 350 non-null    object
# dtypes: object(1)
# memory usage: 5.9+ KB

# %%
df["IsActive"].fillna('Unavailable', inplace=True)
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3216\4188965556.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["IsActive"].fillna('Unavailable', inplace=True)
#      CustomerID            Name   Age  Gender      Country  PurchaseAmount  \
# 0             1    Bob Williams  56.0    Male           UK          128.32
# 1             2   Diana Johnson  69.0    Male        India          522.52
# 5             6     Frank Brown  25.0    Male      Nigeria          931.37
# ...

# %%
df['LastLogin'] = pd.to_datetime(df['LastLogin'], errors = 'coerce')
df
# Out:
#      CustomerID            Name   Age  Gender      Country  PurchaseAmount  \
# 0             1    Bob Williams  56.0    Male           UK          128.32
# 1             2   Diana Johnson  69.0    Male        India          522.52
# 5             6     Frank Brown  25.0    Male      Nigeria          931.37
# 6             7     Alice Jones  38.0  Female      Nigeria          569.20
# 8             9     Henry Smith  36.0  Female        India          545.51
# ..          ...             ...   ...     ...          ...             ...
# 494         495     Frank Smith  23.0    Male        India          202.12
# 495         496  Alice Williams  62.0    Male  Unavailable           19.20
# 496         497  Grace Williams  49.0  Female      Nigeria          186.76
# 498         499    Bob Williams  47.0    Male          USA          284.57
# 499         500    Bob Williams  64.0  Female          USA          203.63
#
#       JoinDate  LastLogin     IsActive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 380 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      380 non-null    int64
#  1   Name            380 non-null    object
#  2   Age             380 non-null    object
#  3   Gender          380 non-null    object
#  4   Country         380 non-null    object
#  5   PurchaseAmount  380 non-null    float64
#  6   JoinDate        380 non-null    datetime64[ns]
#  7   LastLogin       380 non-null    datetime64[ns]
#  8   IsActive        380 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(5)
# memory usage: 29.7+ KB

# %%
df['Age'] = pd.to(df['Age'], errors = 'coerce')
df
# Out:
#      CustomerID            Name   Age  Gender      Country  PurchaseAmount  \
# 0             1    Bob Williams  56.0    Male           UK          128.32
# 1             2   Diana Johnson  69.0    Male        India          522.52
# 5             6     Frank Brown  25.0    Male      Nigeria          931.37
# 6             7     Alice Jones  38.0  Female      Nigeria          569.20
# 8             9     Henry Smith  36.0  Female        India          545.51
# ..          ...             ...   ...     ...          ...             ...
# 494         495     Frank Smith  23.0    Male        India          202.12
# 495         496  Alice Williams  62.0    Male  Unavailable           19.20
# 496         497  Grace Williams  49.0  Female      Nigeria          186.76
# 498         499    Bob Williams  47.0    Male          USA          284.57
# 499         500    Bob Williams  64.0  Female          USA          203.63
#
#       JoinDate  LastLogin     IsActive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 380 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      380 non-null    int64
#  1   Name            380 non-null    object
#  2   Age             380 non-null    float64
#  3   Gender          380 non-null    object
#  4   Country         380 non-null    object
#  5   PurchaseAmount  380 non-null    float64
#  6   JoinDate        380 non-null    datetime64[ns]
#  7   LastLogin       380 non-null    datetime64[ns]
#  8   IsActive        380 non-null    object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(4)
# memory usage: 29.7+ KB

# %%
df.head(30)
# Out:
#     CustomerID             Name        Age  Gender      Country  \
# 0            1     Bob Williams  56.000000    Male           UK
# 1            2    Diana Johnson  69.000000    Male        India
# 5            6      Frank Brown  25.000000    Male      Nigeria
# 6            7      Alice Jones  38.000000  Female      Nigeria
# 8            9      Henry Smith  36.000000  Female        India
# 9           10   Grace Williams  40.000000  Female  Unavailable
# 10          11   Grace Williams  28.000000    Male        Kenya
# 11          12    Frank Johnson  28.000000    Male          USA
# 13          14      Alice Brown  44.091667    Male  Unavailable
# 14          15    Charlie Brown  53.000000    Male           UK
# 16          17        Eve Smith  41.000000  Female  Unavailable
# 17          18    Charlie Brown  20.000000    Male        Kenya
# 18          19    Henry Johnson  39.000000  Female        Kenya
# 19          20  Charlie Johnson  44.091667    Male        Kenya
# ...

# %%
df.to_csv("Cleaned_Messy_dataset.csv", index=False)
